# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set Plot Style
plt.style.use('seaborn-paper')

# %%
# Make a Plot
plt.clf()
fig, ax = plt.subplots(2, sharex = True, figsize = (20,16))

# Import the results of Woodberry - Ideal
Data_Ideal = pd.read_csv('../Modelica/WoodBerry_Ideal.csv')
# Use the steady simulation state from t = 2400...3600
Data = Data_Ideal[((Data_Ideal['time']>2399.9) & (Data_Ideal['time']<3600.1))]
# Get the values
time = Data['time'].values
y1 = Data['y_11.y'].values
y2 = Data['y_22.y'].values
u1 = Data['r_11.y'].values
u2 = Data['r_22.y'].values
IAE1 = Data['IAE_1.y'].values
IAE2 = Data['IAE_2.y'].values
IE1 = Data['IE_1.y'].values
IE2 = Data['IE_2.y'].values
# Set IAE to zero
IAE1 = IAE1-IAE1[0]
IAE2 = IAE2-IAE2[0]

# Make a Plot
plt.clf()
fig, ax = plt.subplots(2, sharex = True, figsize = (10,8))

# y1
ax[0].plot(time, y1)
# y2
ax[1].plot(time,y2, label = "Ideal System")


# Import the results of Woodberry - Decentralized
Data_Decentralized = pd.read_csv('../Modelica/WoodBerry_Decentralized.csv')
# Use the steady simulation state from t = 2400...3600
Data= Data_Decentralized[((Data_Decentralized['time']>2399.9) & (Data_Decentralized['time']<3600.1))]
# Get the values
time = Data['time'].values
y1 = Data['y_11.y'].values
y2 = Data['y_22.y'].values
u1 = Data['r_11.y'].values
u2 = Data['r_22.y'].values
IAE1 = Data['IAE_1.y'].values
IAE2 = Data['IAE_2.y'].values
IE1 = Data['IE_1.y'].values
IE2 = Data['IE_2.y'].values
# Set IAE to zero
IAE1 = IAE1-IAE1[0]
IAE2 = IAE2-IAE2[0]

# Append to plot
# y1
ax[0].plot(time, y1)
# y2
ax[1].plot(time,y2, label = "Decentralized")

# Import the results of Woodberry - Simple Static
Data_Static= pd.read_csv('../Modelica/WoodBerry_Static.csv')
# Use the steady simulation state from t = 2400...3600
Data= Data_Static[((Data_Static['time']>2399.9) & (Data_Static['time']<3600.1))]
# Get the values
time = Data['time'].values
y1 = Data['y_11.y'].values
y2 = Data['y_22.y'].values
u1 = Data['r_11.y'].values
u2 = Data['r_22.y'].values
IAE1 = Data['IAE_1.y'].values
IAE2 = Data['IAE_2.y'].values
IE1 = Data['IE_1.y'].values
IE2 = Data['IE_2.y'].values
# Set IAE to zero
IAE1 = IAE1-IAE1[0]
IAE2 = IAE2-IAE2[0]

# Append to plot
# y1
ax[0].plot(time, y1)
# y2
ax[1].plot(time,y2, label = "Stationary Simple")

# Import the results of Woodberry - Dynamic Simple
Data_Dynamic = pd.read_csv('../Modelica/WoodBerry_Dynamic.csv')
# Use the steady simulation state from t = 2400...3600
Data= Data_Dynamic[((Data_Dynamic['time']>2399.9) & (Data_Dynamic['time']<3600.1))]
# Get the values
time = Data['time'].values
y1 = Data['y_11.y'].values
y2 = Data['y_22.y'].values
u1 = Data['r_11.y'].values
u2 = Data['r_22.y'].values
IAE1 = Data['IAE_1.y'].values
IAE2 = Data['IAE_2.y'].values
IE1 = Data['IE_1.y'].values
IE2 = Data['IE_2.y'].values
# Set IAE to zero
IAE1 = IAE1-IAE1[0]
IAE2 = IAE2-IAE2[0]

# Append to plot
# y1
ax[0].plot(time, y1)
# y2
ax[1].plot(time,y2, label = "Dynamic Simple")

# Import the results of Woodberry - Inverted
Data_Inv = pd.read_csv('../Modelica/WoodBerry_Inverted.csv')
# Use the steady simulation state from t = 2400...3600
Data= Data_Inv[((Data_Inv['time']>2399.9) & (Data_Inv['time']<3600.1))]
# Get the values
time = Data['time'].values
y1 = Data['y_11.y'].values
y2 = Data['y_22.y'].values
u1 = Data['r_11.y'].values
u2 = Data['r_22.y'].values
IAE1 = Data['IAE_1.y'].values
IAE2 = Data['IAE_2.y'].values
IE1 = Data['IE_1.y'].values
IE2 = Data['IE_2.y'].values
# Set IAE to zero
IAE1 = IAE1-IAE1[0]
IAE2 = IAE2-IAE2[0]

# Append to plot
# y1
ax[0].plot(time, y1)
# y2
ax[1].plot(time,y2, label = "Inverted")

# Import the results of Woodberry - Multivariable
Data_Mul = pd.read_csv('../Modelica/WoodBerry_Multivariable.csv')
# Use the steady simulation state from t = 2400...3600
Data= Data_Mul[((Data_Mul['time']>2399.9) & (Data_Mul['time']<3600.1))]
# Get the values
time = Data['time'].values
y1 = Data['y_11.y'].values
y2 = Data['y_22.y'].values
u1 = Data['u_11.y'].values
u2 = Data['u_22.y'].values
IAE1 = Data['IAE_1.y'].values
IAE2 = Data['IAE_2.y'].values
IE1 = Data['IE_1.y'].values
IE2 = Data['IE_2.y'].values
# Set IAE to zero
IAE1 = IAE1-IAE1[0]
IAE2 = IAE2-IAE2[0]

# Append to plot
# y1
ax[0].plot(time, y1)
# y2
ax[1].plot(time,y2, label = "Multivariable")


# Plot Parameter
ax[0].set_ylabel('y_1')
ax[0].grid(True)
ax[1].set_ylabel('y_2')
ax[1].set_xlabel('Time [s]')
ax[1].grid(True)
ax[1].legend(loc = "lower right")
plt.savefig("WoodBerry_All.png")
plt.show()
